# %% [markdown]
# # Harmonic Synthesis Examples
#
# [WIP]
#
# Here we show some more examples of results using gradient descent to optimize a differentiable
# harmonic synthesizer.
#
# For these examples we used the Crepe pitch extraction model, which
# provides a better fundamental frequency envelope.

# %%
import IPython.display as ipd

# %%
ipd.Image("results/string_target.png", width=500)

# %%
ipd.Video("results/guitar-ddsp-torchaudio.mp4")
# Out:
# <video src="results/guitar-ddsp-torchaudio.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
